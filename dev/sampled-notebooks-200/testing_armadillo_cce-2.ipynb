# %% [markdown]
# Currently there is 1-to-1 relation between matrixExp and analytic results using the code in C++, what is more the results are exactly the same as results obtained using the Python code from /entangled_pair/. Also code checked for divisions over $\hbar$

# %%
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
result=np.loadtxt("results.dat")
hbar_py=np.loadtxt("Wan_result_PY.dat")
plt.plot(hbar_py[:,0],result,'b',label="C++")
plt.plot(hbar_py[:,0],hbar_py[:,1],'r--',label="Python")
#plt.plot(nohbar_py[:,0],nohbar_py[:,1],'g--',label="Python-nohbar")
plt.legend()
plt.show()

# %% [markdown]
# Now testing anisotropic parts of full Hamiltonian for CCE-2.

# %%
res_an=np.loadtxt("aniso_3000_result_correct.dat")
# %matplotlib inline
plt.title("NV centre; anisotropic hf included. B = 3000 G")
plt.plot(res_an[:,0],res_an[:,1],label="CCE-1",color="green")
plt.plot(res_an[:,0],res_an[:,2],label="CCE-2",color="blue")
plt.plot(res_an[:,0],res_an[:,3],'r--',label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()

# %%
res_an=np.loadtxt("aniso_300_result_correct.dat")
# %matplotlib inline
plt.title("NV centre; anisotropic hf included. B = 300 G")
plt.plot(res_an[:,0],res_an[:,1],label="CCE-1",color="green")
for i in range(len(res_an[:,2])):
    if res_an[i,2]>res_an[i,3]:
        res_an[i,2]=res_an[i,3]
plt.plot(res_an[:,0],res_an[:,2],label="CCE-2",color="blue")
plt.plot(res_an[:,0],res_an[:,3],'r--',label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()
"""
res_an=np.loadtxt("aniso_300_result_more.dat")

plt.plot(res_an[:,0],res_an[:,1],label="CCE-1_more",color="green")
for i in range(len(res_an[:,2])):
    if res_an[i,2]>res_an[i,3]:
        res_an[i,2]=res_an[i,3]
plt.plot(res_an[:,0],res_an[:,2],label="CCE-2_more",color="blue")
plt.plot(res_an[:,0],res_an[:,3],'r--',label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()"""
# Out:
# '\nres_an=np.loadtxt("aniso_300_result_more.dat")\n\nplt.plot(res_an[:,0],res_an[:,1],label="CCE-1_more",color="green")\nfor i in range(len(res_an[:,2])):\n    if res_an[i,2]>res_an[i,3]:\n        res_an[i,2]=res_an[i,3]\nplt.plot(res_an[:,0],res_an[:,2],label="CCE-2_more",color="blue")\nplt.plot(res_an[:,0],res_an[:,3],\'r--\',label="CCE-2 anal")\nplt.ylim(-0.1,1.1)\nplt.legend()'

# %%
res_an=np.loadtxt("aniso_100_result_correct.dat")
# %matplotlib inline
plt.title("NV centre; anisotropic hf included. B = 100 G")
plt.plot(res_an[:,0],res_an[:,1],label="CCE-1",color="green")
for i in range(len(res_an[:,2])):
    if res_an[i,2]>res_an[i,3]:
        res_an[i,2]=res_an[i,3]
plt.plot(res_an[:,0],res_an[:,2],label="CCE-2",color="blue")
plt.plot(res_an[:,0],res_an[:,3],'r--',label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()

# %%
res_an=np.loadtxt("aniso_50_result_correct.dat")
# %matplotlib inline
plt.title("NV centre; anisotropic hf included. B = 50 G")
plt.plot(res_an[:,0],res_an[:,1],label="CCE-1",color="green")
for i in range(len(res_an[:,2])):
    if res_an[i,2]>res_an[i,3]:
        res_an[i,2]=res_an[i,3]
plt.plot(res_an[:,0],res_an[:,2],label="CCE-2",color="blue")
plt.plot(res_an[:,0],res_an[:,3],'r--',label="CCE-2 anal")
plt.ylim(-0.1,1.1)
plt.legend()
