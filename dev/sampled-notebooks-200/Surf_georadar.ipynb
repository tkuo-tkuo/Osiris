# %%
import numpy
import matplotlib
from scipy.optimize import curve_fit
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=loadtxt('1605a.txt',skiprows=1)
shape(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b4c1443f4231> in <module>()
# ----> 1 data=loadtxt('1605a.txt',skiprows=1)
#       2 shape(data)
#
# NameError: name 'loadtxt' is not defined

# %%
ix=200
iy=512
x=arange(0,200)
y=arange(0,256,0.5)
shape(y)
# Out:
# (512,)

# %%
512*200
# Out:
# 102400

# %%
z=zeros(ix*iy).reshape(iy,ix)

# %%
k=0
for j in range(ix):
    for i in range(iy):
        z[i,j]=float(data[k,2]  )
        
        k=k+1

# %%
ylim(255.5,0)
contourf(x,y,z,256,alpha=0.7,cmap=cm.nipy_spectral)
colorbar()
